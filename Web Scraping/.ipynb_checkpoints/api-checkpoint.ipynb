# %%
import tweepy
import webbrowser
import time
import pandas as pd

# %% [markdown]
# # Authentication

# %%
consumer_key = "bYD7UaDmKVBOr3HjswjTiV6MM"
consumer_secret_key = "qNR3FNURhggb8RgNXnMziSG3LugBvqjAxVuf091ql16c2U5Yud"
callback_url = "oob"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret_key, callback_url)
redirect_url = auth.get_authorization_url()
print(redirect_url)
webbrowser.open(redirect_url)
user_pin_input = input("Pin value: ")
auth.get_access_token(user_pin_input)
# Out:
# https://api.twitter.com/oauth/authorize?oauth_token=9JE9tgAAAAABUbINAAABfFpsp90
# Pin value: 2764819
# ('1313512849659121666-6VqsqQK3yPVl5eS8Pr8JgyTwi2oFBh',
#  'wU2MrTfHm4opkaIkZE8Y19OptmJZQpGT7HSMCsiu0QIwp')

# %%
api = tweepy.API(auth)

# %%
my_friends=''

# %%
def get_friends_list():
    """This function returns list of screen names of user's friends."""
    global my_friends
    friends_list=[]
    if my_friends != '':
        pass #Not requesting again
    else:
        my_friends = api.get_friends()
    for f in my_friends:
        friends_list.append(f.screen_name)
    return friends_list

# %%
def upload_new_status(status_to_upload):
    """This function tweets status. No permission"""
    new_status_check = False
    new_status = api.update_status(status_to_upload)

# %%
user_timeline=''

# %%
def DataOfUser_ToFrame():
    """This function collects data of particular user and passes it to dataframe"""
    global user_timeline
    results = {'Id': [], 'Created_at': [], 'Text': [], 'Url': [],
              'Hastags': [], 'Sybmols': []}
    if user_timeline:
        pass
    else:
        user_timeline = api.get_user(screen_name = "azpresident").timeline()
    for data in user_timeline:
        results['Id'].append(data.id)
        results['Created_at'].append(data.created_at)
        results['Text'].append(data.text)
        results['Url'].append(data.url)
        results['Hastags'].append(data.hastags)
        results['Symbols'].append(data.symbols)
    df=pd.DataFrame(results)
    return df

# %%
df=DataOfUser_ToFrame()
df.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-67-89340e6c8065> in <module>
# ----> 1 df=DataOfUser_ToFrame()
#       2 df.head()
#
# <ipython-input-66-42f5c81560f6> in DataOfUser_ToFrame()
#      12         results['Created_at'].append(data.created_at)
#      13         results['Text'].append(data.text)
# ---> 14         results['Url'].append(data.url)
#      15         results['Hastags'].append(data.hastags)
#      16         results['Symbols'].append(data.symbols)
#
# AttributeError: 'Status' object has no attribute 'url'

# %%
print(user_timeline)
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000021C88B76220>, _json={'created_at': 'Wed Oct 06 12:59:07 +0000 2021', 'id': 1445735370172211208, 'id_str': '1445735370172211208', 'text': 'https://t.co/sT63SOP6AI', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': [], 'media': [{'id': 1445735354435133440, 'id_str': '1445735354435133440', 'indices': [0, 23], 'media_url': 'http://pbs.twimg.com/media/FBBIpSBUYAAFE55.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FBBIpSBUYAAFE55.jpg', 'url': 'https://t.co/sT63SOP6AI', 'display_url': 'pic.twitter.com/sT63SOP6AI', 'expanded_url': 'https://twitter.com/azpresident/status/1445735370172211208/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 670, 'resize': 'fit'}, 'small': {'w': 680, 'h': 380, 'resize': 'fit'}, 'large': {'w': 1928, 'h': 1077, 'resize': 'fit'}}}]}, 'extended_entities': {'media': [{'id': 1445735354435133440, 'id_str': '1445735354435133440', 'indices': [0, 23], 'media_url': 'http://pbs.twimg.com/media/FBBIpSBUYAAFE55.jpg', 'media_url_https': 'https://pbs.twimg.com/media/FBBIpSBUYAAFE55.jpg', 'url': 'https://t.co/sT63SOP6AI', 'display_url': 'pic.twitter.com/sT63SOP6AI', 'expanded_url': 'https://twitter.com/azpresident/status/1445735370172211208/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'medium': {'w': 1200, 'h': 670, 'resize': 'fit'}, 'small': {'w': 680, 'h': 380, 'resize': 'fit'}, 'large': {'w': 1928, 'h': 1077, 'resize': 'fit'}}}]}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 171357785, 'id_str': '171357785', 'name': 'İlham Əliyev', 'screen_name': 'azpresident', 'location': 'Bakı, Azərbaycan', 'description': 'Azərbaycan Respublikasının Prezidenti İlham Əliyevin rəsmi twitter səhifəsi.', 'url': 'http://t.co/D179brFnzV', 'entities': {'url': {'urls': [{'url': 'http://t.co/D179brFnzV', 'expanded_url': 'http://www.president.az', 'display_url': 'president.az', 'indices': [0, 22]}]}, 'description': {'urls': []}}, 'protected': False, 'followers_count': 781463, 'friends_count': 2, 'listed_count': 879, 'created_at': 'Tue Jul 27 04:39:13 +0000 2010', 'favourites_count': 1, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': True, 'statuses_count': 4688, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'C0DEED', 'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png', 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1317884017333723138/3gyjyuL2_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1317884017333723138/3gyjyuL2_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/171357785/1601896098', 'profile_link_color': '0084B4', 'profile_sidebar_border_color': 'FFFFFF', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': False, 'default_profile': False, 'default_profile_image': False, 'following': True, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 169, 'favorite_count': 826, 'favorited': False, 'retweeted': False, 'possibly_sensitive': False, 'lang': 'und'}, created_at=datetime.datetime(2021, 10, 6, 12, 59, 7, tzinfo=datetime.timezone.utc), id=1445735370172211208, id_str='1445735370172211208', text='https://t.co/sT63SOP6AI', truncated=False, entities={'hashtag ...

# %%
for i in user_timeline:
    print(i.text)
# Out:
# https://t.co/sT63SOP6AI
# https://t.co/Q6l59HpP87
# https://t.co/B5tOvL2Q1d
# Neçə dəfə bizi devirmək istəmişdilər? Bunu Azərbaycan xalqı yaxşı bilir, bunu mən yaxşı bilirəm, çünki bəzi xarici… https://t.co/JPHhWB5O0N
# Əgər Azərbaycan xalqı 1993-cü ildə özünə xas olan müdriklik göstərməsəydi, Ulu Öndəri dəvət etməsəydi, Azərbaycanın… https://t.co/a9SjuDCDFM
# Cəbrayıl şəhərinin baş planı siz cəbrayıllılara təqdim ediləcək. Biz bu plana bərabər baxacağıq. Əgər razılığınız o… https://t.co/uEUOsL8VSz
# Azərbaycan tərəfində siyasi iradə var. Ermənistan tərəfində də olarsa, hesab edirəm ki, iki ölkə özləri heç bir vas… https://t.co/oumEI5QzM9
# Ermənistan rəhbərliyi ən yüksək səviyyədə açıq-aydın bəyan edir ki, Azərbaycan Gorus-Qafan yolunun müəyyən hissəsin… https://t.co/bIX811EUmK
# Biz 130 kilometr Azərbaycan-İran sərhədini işğalçılardan təmizlədik. 130 kilometr Ermənistanın işğalı altında idi.… https://t.co/5UtvmmjBr2
# Düz bir il əvvəl məhz oktyabrın 4-də Azərbaycan Ordusu Cəbrayıl şəhərini işğalçılardan azad etdi və bu gün bu şanlı… https://t.co/sRVat0JBWt
# https://t.co/VQZCO9ia4X
# https://t.co/Dq5rLGUmiI
# https://t.co/zaa9Bfsfyj
# İşğal zamanı mənfur düşmən bizə qarşı ekoloji terror da törədirdi, su terroru törədirdi. Hətta Avropa Şurası Parlam… https://t.co/7frx2NPulY
# Burada çox güclü istehkamlar qurulmuşdu, bir neçə müdafiə xətti təşkil edilmişdi. Bütün strateji yüksəkliklərdə, qə… https://t.co/leSTFIRlhz
# Bax, iki saxtakar - biri ATƏT-in Demokratik Təsisatlar və İnsan Haqları Bürosu, hansı ki, Azərbaycana hər zaman xor… https://t.co/MTbPcLgpzk
# Bu ordunu yaradan Serjik deyil, kimdir? Biz o ordunu məhv etməklə Serjiki və onun kimi ünsürləri məhv etdik. https://t.co/VUgQiiCKrY
# Bu gün Suqovuşanda və Talış kəndində olarkən bir daha xalqımızın, Silahlı Qüvvələrimizin qəhrəmanlığını görürəm. Bu… https://t.co/jkCldLtWG9
# https://t.co/e546U7VwFz
# https://t.co/8FqlYy0ASH

# %%
my_timeline = api.home_timeline()
print(my_timeline)
# Out:
# [Status(_api=<tweepy.api.API object at 0x0000021C887BD670>, _json={'created_at': 'Thu Oct 07 10:01:17 +0000 2021', 'id': 1446053005917315072, 'id_str': '1446053005917315072', 'text': 'Lorem ipsum 2', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, 'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>', 'in_reply_to_status_id': None, 'in_reply_to_status_id_str': None, 'in_reply_to_user_id': None, 'in_reply_to_user_id_str': None, 'in_reply_to_screen_name': None, 'user': {'id': 1313512849659121666, 'id_str': '1313512849659121666', 'name': 'Teymur', 'screen_name': 'Tima_601', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 14, 'friends_count': 29, 'listed_count': 0, 'created_at': 'Tue Oct 06 16:14:13 +0000 2020', 'favourites_count': 46, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 3, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1443981686438600724/XiXkpHBF_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1443981686438600724/XiXkpHBF_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1313512849659121666/1633107038', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow_request_sent': False, 'notifications': False, 'translator_type': 'none', 'withheld_in_countries': []}, 'geo': None, 'coordinates': None, 'place': None, 'contributors': None, 'is_quote_status': False, 'retweet_count': 0, 'favorite_count': 0, 'favorited': False, 'retweeted': False, 'lang': 'en'}, created_at=datetime.datetime(2021, 10, 7, 10, 1, 17, tzinfo=datetime.timezone.utc), id=1446053005917315072, id_str='1446053005917315072', text='Lorem ipsum 2', truncated=False, entities={'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []}, source='Twitter Web App', source_url='https://mobile.twitter.com', in_reply_to_status_id=None, in_reply_to_status_id_str=None, in_reply_to_user_id=None, in_reply_to_user_id_str=None, in_reply_to_screen_name=None, author=User(_api=<tweepy.api.API object at 0x0000021C887BD670>, _json={'id': 1313512849659121666, 'id_str': '1313512849659121666', 'name': 'Teymur', 'screen_name': 'Tima_601', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_count': 14, 'friends_count': 29, 'listed_count': 0, 'created_at': 'Tue Oct 06 16:14:13 +0000 2020', 'favourites_count': 46, 'utc_offset': None, 'time_zone': None, 'geo_enabled': False, 'verified': False, 'statuses_count': 3, 'lang': None, 'contributors_enabled': False, 'is_translator': False, 'is_translation_enabled': False, 'profile_background_color': 'F5F8FA', 'profile_background_image_url': None, 'profile_background_image_url_https': None, 'profile_background_tile': False, 'profile_image_url': 'http://pbs.twimg.com/profile_images/1443981686438600724/XiXkpHBF_normal.jpg', 'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1443981686438600724/XiXkpHBF_normal.jpg', 'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1313512849659121666/1633107038', 'profile_link_color': '1DA1F2', 'profile_sidebar_border_color': 'C0DEED', 'profile_sidebar_fill_color': 'DDEEF6', 'profile_text_color': '333333', 'profile_use_background_image': True, 'has_extended_profile': True, 'default_profile': True, 'default_profile_image': False, 'following': False, 'follow ...

# %%
for m in my_timeline:
    print(m.text)
    print(m.created_at)
    print(m.id)
# Out:
# Lorem ipsum 2
# 2021-10-07 10:01:17+00:00
# 1446053005917315072
# Lorem ipsum dummy test
# 2021-10-07 10:01:05+00:00
# 1446052953748647937
# Christian Horner 🗣 "Our ambitious and exciting Red Bull Powertrains project will be strongly supported by Honda"… https://t.co/yb2BeqhRu5
# 2021-10-07 09:19:54+00:00
# 1446042590135132160
# Out of an abundance of caution, we have reset all stream keys. You can get your new stream key here:… https://t.co/tU0CZ0hF6I
# 2021-10-07 08:45:21+00:00
# 1446033897234513920
# A special @redbullracing thank you and goodbye to @HondaRacingF1 🥰
#
# #TurkishGP 🇹🇷 #F1
#
# https://t.co/0ZqDsR8JDh
# 2021-10-07 08:03:48+00:00
# 1446023440478130178
# Fresh look for the weekend 🤍 Simply lovely 👌 ありがとう @HondaRacingF1 #TurkishGP https://t.co/IPFA3cAvmY
# 2021-10-07 06:24:10+00:00
# 1445998364307431424
# A MEGA tribute to @HondaRacingF1 😍🤍
#
# 📸 x @redbullracing
#
# #TurkishGP 🇹🇷 #F1 https://t.co/f8wPjXMrYs
# 2021-10-07 06:18:24+00:00
# 1445996913640230913
# RT @redbullracing: The Bull in 🤍 #PoweredByHonda 🇯🇵 https://t.co/24weGNCRwa
# 2021-10-07 06:12:29+00:00
# 1445995424796528642
# RT @redbullracing: The 𝗙𝗨𝗟𝗟 reveal 👋🇯🇵 Unveiling our very special livery for the #TurkishGP 🤍 https://t.co/mcgQldasiH
# 2021-10-07 06:01:38+00:00
# 1445992695999209472
# Our investigation is ongoing, and we are in the process of analyzing all of the relevant logs and data to assess ac… https://t.co/gz0UqlslXq
# 2021-10-07 05:33:27+00:00
# 1445985601174392835
# Checo was on the podium in Turkey last year 🥈
#
# The Mexican is determined to repeat the feat this season after a ru… https://t.co/bLiLm1oslz
# 2021-10-06 21:23:00+00:00
# 1445862175986184197
# Fernando and Michael fight to the finish 💪🍿
#
# #TurkishGP 🇹🇷 #F1 https://t.co/ywA8tCQ2zg
# 2021-10-06 20:07:00+00:00
# 1445843049893044224
# Inspiring the next generation of #F1 racers 👍
#
# @LandoNorris is on a mission to get more girls and boys karting 🙌
#
# #F1
# 2021-10-06 19:24:00+00:00
# 1445832228647235585
# What's it like to drive on rain-drenched tracks? ☔️ Our latest guest on the #F1BeyondTheGrid podcast knows!
#
# Itali… https://t.co/RnGmcjpc1C
# 2021-10-06 18:33:00+00:00
# 1445819394332905477
# You think I'd go all the way to Italy, launch a kart, and not film you a LandoLOG? 😉
#
# https://t.co/750YI8D7SI https://t.co/RYtnyGQEuJ
# 2021-10-06 17:44:08+00:00
# 1445807097103282178
# A title battle for the ages
#
# #F1 https://t.co/p39JTysCJz
# 2021-10-06 17:01:00+00:00
# 1445796241812639745
# The 2021 F1 Esports Pro Championship is just one week away!
#
# And there's a LOT to look forward to this year 😍… https://t.co/VpoERIEv4o
# 2021-10-06 15:45:00+00:00
# 1445777115929006080
# Sticking it on P1 in the pouring rain ☔️👏
#
# @lance_stroll's maiden pole was a special lap 💪
#
# #TurkishGP 🇹🇷 #F1 https://t.co/xijHUvL1d3
# 2021-10-06 15:24:07+00:00
# 1445771863032954886
# RT @MinecraftMarket: Whether it’s sinister creatures lurking on the ocean floor; an eerie moon affecting those on the surface, or a suspici…
# 2021-10-06 15:20:13+00:00
# 1445770881322520583
# We can confirm a breach has taken place. Our teams are working with urgency to understand the extent of this. We wi… https://t.co/ViirlT1qt1
# 2021-10-06 15:18:28+00:00
# 1445770441176469512

# %%
dir(api)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'add_list_member',
#  'add_list_members',
#  'auth',
#  'available_trends',
#  'cache',
#  'cached_result',
#  'chunked_upload',
#  'chunked_upload_append',
#  'chunked_upload_finalize',
#  'chunked_upload_init',
#  'closest_trends',
#  'create_block',
#  'create_favorite',
#  'create_friendship',
#  'create_list',
#  'create_media_metadata',
#  'create_mute',
#  'create_saved_search',
#  'delete_direct_message',
#  'destroy_block',
#  'destroy_favorite',
#  'destroy_friendship',
#  'destroy_list',
#  'destroy_mute',
#  'destroy_saved_search',
#  'destroy_status',
#  'geo_id',
#  'get_blocked_ids',
#  'get_blocks',
#  'get_direct_message',
#  'get_direct_messages',
#  'get_favorites',
#  'get_follower_ids',
#  'get_followers',
#  'get_friend_ids',
#  'get_friends',
#  'get_friendship',
#  'get_list',
#  'get_list_member',
#  'get_list_members',
#  'get_list_memberships',
#  'get_list_ownerships',
#  'get_list_subscriber',
#  'get_list_subscribers',
#  'get_list_subscriptions',
#  'get_lists',
#  'get_media_upload_status',
#  'get_muted_ids',
#  'get_mutes',
#  'get_oembed',
#  'get_place_trends',
#  'get_profile_banner',
#  'get_retweeter_ids',
#  'get_retweets',
#  'get_retweets_of_me',
#  'get_saved_search',
#  'get_saved_searches',
#  'get_settings',
#  'get_status',
#  'get_user',
#  'home_timeline',
#  'host',
#  'incoming_friendships',
#  'last_response',
#  'list_timeline',
#  'lookup_friendships',
#  'lookup_statuses',
#  'lookup_users',
#  'media_upload',
#  'mentions_timeline',
#  'no_retweets_friendships',
#  'outgoing_friendships',
#  'parser',
#  'proxy',
#  'rate_limit_status',
#  'remove_list_member',
#  'remove_list_members',
#  'remove_profile_banner',
#  'report_spam',
#  'request',
#  'retry_count',
#  'retry_delay',
#  'retry_errors',
#  'retweet',
#  'reverse_geocode',
#  'search_30_day',
#  'search_full_archive',
#  'search_geo',
#  'search_tweets',
#  'search_users',
#  'send_direct_message',
#  'session',
#  'set_settings',
#  'simple_upload',
#  'subscribe_list',
#  'supported_languages',
#  'timeout',
#  'unretweet',
#  'unsubscribe_list',
#  'update_friendship',
#  'update_list',
#  'update_profile',
#  'update_profile_banner',
#  'update_profile_image',
#  'update_status',
#  'update_status_with_media',
#  'upload_host',
#  'user_agent',
#  'user_timeline',
#  'verify_credentials',
#  'wait_on_rate_limit']
